# %% [markdown]
# # This is pandas documentation

# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,2,3,np.nan,5,6])
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# 5    6.0
# dtype: float64

# %%
dates=pd.date_range('20220101',periods=7)
dates
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates=pd.date_range('20220101',periods=7)

df=pd.DataFrame(np.random.randn(7,4),index=dates,columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684

# %%
df2=pd.DataFrame(
    {
        'A' : 1.0,
        'B' : pd.Timestamp('20220101'),
        'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
        'D' : np.array([3]*4,dtype='int32'),
        'E' : pd.Categorical(['food','ear','food','eat']),
        'F' : 'DATA',
    }
)
df2
# Out:
#      A          B    C  D     E     F
# 0  1.0 2022-01-01  1.0  3  food  DATA
# 1  1.0 2022-01-01  1.0  3   ear  DATA
# 2  1.0 2022-01-01  1.0  3  food  DATA
# 3  1.0 2022-01-01  1.0  3   eat  DATA

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %% [markdown]
# - Viewing data

# %%
df.head()
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684

# %%
df.index
# Out:
# DatetimeIndex(['2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06', '2022-01-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 1.30113126e+00, -2.50385993e-01,  5.89539401e-01,
#         -8.58970823e-02],
#        [ 5.94889566e-01, -1.51107141e+00,  2.04084194e+00,
#          2.06874577e-01],
#        [ 5.27439347e-02, -2.73099226e-03, -7.77988060e-01,
#         -4.83824624e-01],
#        [ 1.28494793e+00, -1.75498098e+00, -1.80566955e-01,
#          8.85902998e-01],
#        [-2.40847004e-01, -7.30120382e-01,  3.49621224e-01,
#          1.11755858e+00],
#        [-1.54343853e+00, -1.23036869e-01,  6.49528162e-01,
#          3.72123677e-01],
#        [ 2.77981535e-01, -3.83365565e-01,  2.78061980e+00,
#         -4.36683579e-01]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2022-01-01 00:00:00'), 1.0, 3, 'food', 'DATA'],
#        [1.0, Timestamp('2022-01-01 00:00:00'), 1.0, 3, 'ear', 'DATA'],
#        [1.0, Timestamp('2022-01-01 00:00:00'), 1.0, 3, 'food', 'DATA'],
#        [1.0, Timestamp('2022-01-01 00:00:00'), 1.0, 3, 'eat', 'DATA']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  7.000000  7.000000  7.000000  7.000000
# mean   0.246773 -0.679385  0.778799  0.225151
# std    0.982507  0.694050  1.236981  0.618108
# min   -1.543439 -1.754981 -0.777988 -0.483825
# 25%   -0.094052 -1.120596  0.084527 -0.261290
# 50%    0.277982 -0.383366  0.589539  0.206875
# 75%    0.939919 -0.186711  1.345185  0.629013
# max    1.301131 -0.002731  2.780620  1.117559

# %%
df2.describe()
# Out:
#          A    C    D
# count  4.0  4.0  4.0
# mean   1.0  1.0  3.0
# std    0.0  0.0  0.0
# min    1.0  1.0  3.0
# 25%    1.0  1.0  3.0
# 50%    1.0  1.0  3.0
# 75%    1.0  1.0  3.0
# max    1.0  1.0  3.0

# %%
df
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684

# %%
# Transpose the data
df.T
# Out:
#    2022-01-01  2022-01-02  2022-01-03  2022-01-04  2022-01-05  2022-01-06  \
# A    1.301131    0.594890    0.052744    1.284948   -0.240847   -1.543439
# B   -0.250386   -1.511071   -0.002731   -1.754981   -0.730120   -0.123037
# C    0.589539    2.040842   -0.777988   -0.180567    0.349621    0.649528
# D   -0.085897    0.206875   -0.483825    0.885903    1.117559    0.372124
#
#    2022-01-07
# A    0.277982
# B   -0.383366
# C    2.780620
# D   -0.436684

# %% [markdown]
# * sorting by axis

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2022-01-01 -0.085897  0.589539 -0.250386  1.301131
# 2022-01-02  0.206875  2.040842 -1.511071  0.594890
# 2022-01-03 -0.483825 -0.777988 -0.002731  0.052744
# 2022-01-04  0.885903 -0.180567 -1.754981  1.284948
# 2022-01-05  1.117559  0.349621 -0.730120 -0.240847
# 2022-01-06  0.372124  0.649528 -0.123037 -1.543439
# 2022-01-07 -0.436684  2.780620 -0.383366  0.277982

# %%
df.sort_index(axis=1,ascending=True)
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#                    A         B         C         D
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897

# %%
df.sort_index(axis=0,ascending=True)
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684

# %% [markdown]
# - Sortng by values

# %%
df
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684

# %%
# it automatically sort the value in asending order of given column
df.sort_values(by='B')
# Out:
#                    A         B         C  D    F
# 2022-01-04  1.284948 -1.754981 -0.180567  5  3.0
# 2022-01-02  0.594890 -1.511071  2.040842  5  1.0
# 2022-01-05 -0.240847 -0.730120  0.349621  5  4.0
# 2022-01-07  0.277982 -0.383366  2.780620  5  6.0
# 2022-01-06 -1.543439 -0.123037  0.649528  5  5.0
# 2022-01-03  0.052744 -0.002731 -0.777988  5  2.0
# 2022-01-01  0.000000  0.000000  0.589539  5  NaN

# %% [markdown]
# # - selection method

# %%
df['A']
# Out:
# 2022-01-01    1.301131
# 2022-01-02    0.594890
# 2022-01-03    0.052744
# 2022-01-04    1.284948
# 2022-01-05   -0.240847
# 2022-01-06   -1.543439
# 2022-01-07    0.277982
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825

# %%
df
# Out:
#                    A         B         C  D    F
# 2022-01-01  0.000000  0.000000  0.589539  5  NaN
# 2022-01-02  0.594890 -1.511071  2.040842  5  1.0
# 2022-01-03  0.052744 -0.002731 -0.777988  5  2.0
# 2022-01-04  1.284948 -1.754981 -0.180567  5  3.0
# 2022-01-05 -0.240847 -0.730120  0.349621  5  4.0
# 2022-01-06 -1.543439 -0.123037  0.649528  5  5.0
# 2022-01-07  0.277982 -0.383366  2.780620  5  6.0

# %%
# Hoe do i get values of A and B only 
# df[0:3]
df.iloc[:2,:2]
# Out:
#                   A         B
# 2022-01-01  0.00000  0.000000
# 2022-01-02  0.59489 -1.511071

# %%
df['20220101':'20220104']
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903

# %% [markdown]
# # selection by lebels

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2022-01-01  1.301131 -0.250386
# 2022-01-02  0.594890 -1.511071
# 2022-01-03  0.052744 -0.002731
# 2022-01-04  1.284948 -1.754981
# 2022-01-05 -0.240847 -0.730120
# 2022-01-06 -1.543439 -0.123037
# 2022-01-07  0.277982 -0.383366

# %%
df.loc[dates[0]]
# Out:
# A    1.301131
# B   -0.250386
# C    0.589539
# D   -0.085897
# Name: 2022-01-01 00:00:00, dtype: float64

# %%
df.loc['20220101':'20220104',['A','B']]
# Out:
#                    A         B
# 2022-01-01  1.301131 -0.250386
# 2022-01-02  0.594890 -1.511071
# 2022-01-03  0.052744 -0.002731
# 2022-01-04  1.284948 -1.754981

# %%
df.loc[:,['A','B']]
# Out:
#                    A         B
# 2022-01-01  1.301131 -0.250386
# 2022-01-02  0.594890 -1.511071
# 2022-01-03  0.052744 -0.002731
# 2022-01-04  1.284948 -1.754981
# 2022-01-05 -0.240847 -0.730120
# 2022-01-06 -1.543439 -0.123037
# 2022-01-07  0.277982 -0.383366

# %%
df.loc['20220101',['A','B']]
# Out:
# A    1.301131
# B   -0.250386
# Name: 2022-01-01 00:00:00, dtype: float64

# %%
df.loc[dates[0],'A']
# Out:
# 1.3011312598774685

# %%
df.at[dates[0],'A']
# Out:
# 1.3011312598774685

# %%
# by integer slice , acting similer to NumPy we use iloc
# use iloc
df.iloc[0:3,0:4]
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825

# %%
df.iloc[[1,2,4],[1,2]]
# Out:
#                    B         C
# 2022-01-02 -1.511071  2.040842
# 2022-01-03 -0.002731 -0.777988
# 2022-01-05 -0.730120  0.349621

# %%
# For slicing rows 

df.iloc[1:3,:]
# Out:
#                    A         B         C         D
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825

# %%
# For slicing column

df.iloc[:,0:3]
# Out:
#                    A         B         C
# 2022-01-01  1.301131 -0.250386  0.589539
# 2022-01-02  0.594890 -1.511071  2.040842
# 2022-01-03  0.052744 -0.002731 -0.777988
# 2022-01-04  1.284948 -1.754981 -0.180567
# 2022-01-05 -0.240847 -0.730120  0.349621
# 2022-01-06 -1.543439 -0.123037  0.649528
# 2022-01-07  0.277982 -0.383366  2.780620

# %%
df.iloc[:2,:2]
# Out:
#                    A         B
# 2022-01-01  1.301131 -0.250386
# 2022-01-02  0.594890 -1.511071

# %%
# For getting values

df.iloc[1,1]
# Out:
# -1.5110714121741222

# %%
df
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684

# %%
# How to get 0.672559
df.iloc[5,3]
# Out:
# 0.37212367741562524

# %%
# Boolean Indexing
df[df['A']>0]
# Out:
#                    A         B         C         D
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684

# %%
df['A']<0
# Out:
# 2022-01-01    False
# 2022-01-02    False
# 2022-01-03    False
# 2022-01-04    False
# 2022-01-05     True
# 2022-01-06     True
# 2022-01-07    False
# Freq: D, Name: A, dtype: bool

# %%
df[df['A']<0]
# Out:
#                    A         B         C         D
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124

# %%
df[df>0]
# Out:
#                    A   B         C  D    F
# 2022-01-01       NaN NaN  0.589539  5  NaN
# 2022-01-02  0.594890 NaN  2.040842  5  1.0
# 2022-01-03  0.052744 NaN       NaN  5  2.0
# 2022-01-04  1.284948 NaN       NaN  5  3.0
# 2022-01-05       NaN NaN  0.349621  5  4.0
# 2022-01-06       NaN NaN  0.649528  5  5.0
# 2022-01-07  0.277982 NaN  2.780620  5  6.0

# %%
df2=df.copy()
df2['E']=['one','two','three','four','five','six','seven']
df2
# Out:
#                    A         B         C         D      E
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897    one
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875    two
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825  three
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903   four
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559   five
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124    six
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684  seven

# %%
df2[df2['E'].isin(['two','four'])]
# Out:
#                    A         B         C         D     E
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875   two
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903  four

# %%
s1=pd.Series([1,2,3,4,5,6,7],index=pd.date_range('20220102',periods=7))
s1
df['F']=s1
df
# Out:
#                    A         B         C         D    F
# 2022-01-01  1.301131 -0.250386  0.589539 -0.085897  NaN
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875  1.0
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825  2.0
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903  3.0
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559  4.0
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124  5.0
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684  6.0

# %%
df.at[dates[0],'A']=0
df
# Out:
#                    A         B         C         D    F
# 2022-01-01  0.000000 -0.250386  0.589539 -0.085897  NaN
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875  1.0
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825  2.0
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903  3.0
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559  4.0
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124  5.0
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684  6.0

# %%
df.iat[0,1]=0
df
# Out:
#                    A         B         C         D    F
# 2022-01-01  0.000000  0.000000  0.589539 -0.085897  NaN
# 2022-01-02  0.594890 -1.511071  2.040842  0.206875  1.0
# 2022-01-03  0.052744 -0.002731 -0.777988 -0.483825  2.0
# 2022-01-04  1.284948 -1.754981 -0.180567  0.885903  3.0
# 2022-01-05 -0.240847 -0.730120  0.349621  1.117559  4.0
# 2022-01-06 -1.543439 -0.123037  0.649528  0.372124  5.0
# 2022-01-07  0.277982 -0.383366  2.780620 -0.436684  6.0

# %%
df.loc[:,'D']=np.array([5]*len(df))

df
# Out:
#                    A         B         C  D    F
# 2022-01-01  0.000000  0.000000  0.589539  5  NaN
# 2022-01-02  0.594890 -1.511071  2.040842  5  1.0
# 2022-01-03  0.052744 -0.002731 -0.777988  5  2.0
# 2022-01-04  1.284948 -1.754981 -0.180567  5  3.0
# 2022-01-05 -0.240847 -0.730120  0.349621  5  4.0
# 2022-01-06 -1.543439 -0.123037  0.649528  5  5.0
# 2022-01-07  0.277982 -0.383366  2.780620  5  6.0

# %%
df2=df.copy()
df2[df2>0]=-df2
df2
# Out:
#                    A         B         C  D    F
# 2022-01-01  0.000000  0.000000 -0.589539 -5  NaN
# 2022-01-02 -0.594890 -1.511071 -2.040842 -5 -1.0
# 2022-01-03 -0.052744 -0.002731 -0.777988 -5 -2.0
# 2022-01-04 -1.284948 -1.754981 -0.180567 -5 -3.0
# 2022-01-05 -0.240847 -0.730120 -0.349621 -5 -4.0
# 2022-01-06 -1.543439 -0.123037 -0.649528 -5 -5.0
# 2022-01-07 -0.277982 -0.383366 -2.780620 -5 -6.0

# %% [markdown]
# - Missing data

# %%
df1=df.reindex(index=dates[0:4], columns=list(df.columns)+['E'])
df1
# Out:
#                    A         B         C  D    F   E
# 2022-01-01  0.000000  0.000000  0.589539  5  NaN NaN
# 2022-01-02  0.594890 -1.511071  2.040842  5  1.0 NaN
# 2022-01-03  0.052744 -0.002731 -0.777988  5  2.0 NaN
# 2022-01-04  1.284948 -1.754981 -0.180567  5  3.0 NaN

# %%
df1=df.reindex(index=dates[0:4], columns=list(df.columns)+['E'])
df1.loc[dates[0]:dates[1],'E']=1
df1
# Out:
#                    A         B         C  D    F    E
# 2022-01-01  0.000000  0.000000  0.589539  5  NaN  1.0
# 2022-01-02  0.594890 -1.511071  2.040842  5  1.0  1.0
# 2022-01-03  0.052744 -0.002731 -0.777988  5  2.0  NaN
# 2022-01-04  1.284948 -1.754981 -0.180567  5  3.0  NaN

# %%
 # Drop any row which has missing data
dd=df1.dropna(how='any')
dd
# Out:
#                   A         B         C  D    F    E
# 2022-01-02  0.59489 -1.511071  2.040842  5  1.0  1.0

# %%
# filling value at missing place

df1.fillna(value=3)
# Out:
#                    A         B         C  D    F    E
# 2022-01-01  0.000000  0.000000  0.589539  5  3.0  1.0
# 2022-01-02  0.594890 -1.511071  2.040842  5  1.0  1.0
# 2022-01-03  0.052744 -0.002731 -0.777988  5  2.0  3.0
# 2022-01-04  1.284948 -1.754981 -0.180567  5  3.0  3.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2022-01-01  False  False  False  False   True  False
# 2022-01-02  False  False  False  False  False  False
# 2022-01-03  False  False  False  False  False   True
# 2022-01-04  False  False  False  False  False   True

# %% [markdown]
# * Operation

# %%
df.mean()
# Out:
# A    0.060897
# B   -0.643615
# C    0.778799
# D    5.000000
# F    3.500000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2022-01-01    1.397385
# 2022-01-02    1.424932
# 2022-01-03    1.254405
# 2022-01-04    1.469880
# 2022-01-05    1.675731
# 2022-01-06    1.796611
# 2022-01-07    2.735047
# Freq: D, dtype: float64

# %%
df
# Out:
#                    A         B         C  D    F
# 2022-01-01  0.000000  0.000000  0.589539  5  NaN
# 2022-01-02  0.594890 -1.511071  2.040842  5  1.0
# 2022-01-03  0.052744 -0.002731 -0.777988  5  2.0
# 2022-01-04  1.284948 -1.754981 -0.180567  5  3.0
# 2022-01-05 -0.240847 -0.730120  0.349621  5  4.0
# 2022-01-06 -1.543439 -0.123037  0.649528  5  5.0
# 2022-01-07  0.277982 -0.383366  2.780620  5  6.0

# %%
df.mean(0)
# Out:
# A    0.060897
# B   -0.643615
# C    0.778799
# D    5.000000
# F    3.500000
# dtype: float64

# %%
s=pd.Series([1,2,3,4,np.nan,4,5],index=dates).shift(2)
s
# Out:
# 2022-01-01    NaN
# 2022-01-02    NaN
# 2022-01-03    1.0
# 2022-01-04    2.0
# 2022-01-05    3.0
# 2022-01-06    4.0
# 2022-01-07    NaN
# Freq: D, dtype: float64

# %%
df.sub(s , axis='index')
# Out:
#                    A         B         C    D    F
# 2022-01-01       NaN       NaN       NaN  NaN  NaN
# 2022-01-02       NaN       NaN       NaN  NaN  NaN
# 2022-01-03 -0.947256 -1.002731 -1.777988  4.0  1.0
# 2022-01-04 -0.715052 -3.754981 -2.180567  3.0  1.0
# 2022-01-05 -3.240847 -3.730120 -2.650379  2.0  1.0
# 2022-01-06 -5.543439 -4.123037 -3.350472  1.0  1.0
# 2022-01-07       NaN       NaN       NaN  NaN  NaN

# %%
# Apply function to the data
df.apply(np.cumsum)
# Out:
#                    A         B         C         D          F
# 2022-01-01  0.000000  0.000000  0.589539  5.589539        NaN
# 2022-01-02  0.594890 -0.916182  1.124660  6.124660   7.124660
# 2022-01-03  0.052744  0.050013 -0.727975  4.272025   6.272025
# 2022-01-04  1.284948 -0.470033 -0.650600  4.349400   7.349400
# 2022-01-05 -0.240847 -0.970967 -0.621346  4.378654   8.378654
# 2022-01-06 -1.543439 -1.666475 -1.016947  3.983053   8.983053
# 2022-01-07  0.277982 -0.105384  2.675236  7.675236  13.675236

# %%
df.apply(np.cumsum,axis=0)
# Out:
#                    A         B         C   D     F
# 2022-01-01  0.000000  0.000000  0.589539   5   NaN
# 2022-01-02  0.594890 -1.511071  2.630381  10   1.0
# 2022-01-03  0.647634 -1.513802  1.852393  15   3.0
# 2022-01-04  1.932581 -3.268783  1.671826  20   6.0
# 2022-01-05  1.691734 -3.998904  2.021448  25  10.0
# 2022-01-06  0.148296 -4.121941  2.670976  30  15.0
# 2022-01-07  0.426277 -4.505306  5.451596  35  21.0

# %%
df
# Out:
#                    A         B         C  D    F
# 2022-01-01  0.000000  0.000000  0.589539  5  NaN
# 2022-01-02  0.594890 -1.511071  2.040842  5  1.0
# 2022-01-03  0.052744 -0.002731 -0.777988  5  2.0
# 2022-01-04  1.284948 -1.754981 -0.180567  5  3.0
# 2022-01-05 -0.240847 -0.730120  0.349621  5  4.0
# 2022-01-06 -1.543439 -0.123037  0.649528  5  5.0
# 2022-01-07  0.277982 -0.383366  2.780620  5  6.0

# %%
df.apply(lambda x : x.max() - x.min())
# Out:
# A    2.828386
# B    1.754981
# C    3.558608
# D    0.000000
# F    5.000000
# dtype: float64

# %%
# Histogramming 
s=pd.Series(np.random.randint(0,7,size=10))
s
# Out:
# 0    6
# 1    5
# 2    4
# 3    2
# 4    5
# 5    2
# 6    0
# 7    5
# 8    5
# 9    3
# dtype: int32

# %%
# kon se value kitne baar aayi hai

s.value_counts()
# Out:
# 5    4
# 2    2
# 6    1
# 4    1
# 0    1
# 3    1
# dtype: int64

# %%
# string method
s=pd.Series(['A','B','C',np.nan,'ABD','FGJK',"GOR"])
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3     NaN
# 4     abd
# 5    fgjk
# 6     gor
# dtype: object

# %%
df=pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0  0.146160 -0.682223  1.087869  0.819292
# 1  0.741416  1.817740  0.886702  0.997287
# 2 -1.423537 -1.926221 -0.262723  0.959520
# 3  0.811579 -0.003475  0.219576  0.994507
# 4 -0.020361 -0.465377  0.098788  0.099133
# 5  1.174897  0.610943  1.279198  0.317052
# 6 -1.629785 -1.815228 -0.910904 -1.248898
# 7  0.828451 -0.827930 -1.368876  0.410791
# 8  0.943444  0.681877 -0.215388 -0.722456
# 9  0.186416  0.379239  0.058347  0.213965

# %%
piece=[df[:3],df[3:7],df[7:1]]
piece
# Out:
# [          0         1         2         3
#  0  0.146160 -0.682223  1.087869  0.819292
#  1  0.741416  1.817740  0.886702  0.997287
#  2 -1.423537 -1.926221 -0.262723  0.959520,
#            0         1         2         3
#  3  0.811579 -0.003475  0.219576  0.994507
#  4 -0.020361 -0.465377  0.098788  0.099133
#  5  1.174897  0.610943  1.279198  0.317052
#  6 -1.629785 -1.815228 -0.910904 -1.248898,
#  Empty DataFrame
#  Columns: [0, 1, 2, 3]
#  Index: []]
