# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv('FAOSTAT_data.csv')
data
# Out:
#    Domain Code    Domain  Area Code   Area  Element Code Element  Item Code  \
# 0           RL  Land Use        100  India          5110    Area       6610
# 1           RL  Land Use        100  India          5110    Area       6610
# 2           RL  Land Use        100  India          5110    Area       6610
# 3           RL  Land Use        100  India          5110    Area       6610
# 4           RL  Land Use        100  India          5110    Area       6610
# ..         ...       ...        ...    ...           ...     ...        ...
# 84          RL  Land Use        100  India          5110    Area       6610
# 85          RL  Land Use        100  India          5110    Area       6610
# 86          RL  Land Use        100  India          5110    Area       6670
# 87          RL  Land Use        100  India          5110    Area       6670
# 88          RL  Land Use        100  India          5110    Area       6610
#
# ...

# %%
data.head()
# Out:
#   Domain Code    Domain  Area Code   Area  Element Code Element  Item Code  \
# 0          RL  Land Use        100  India          5110    Area       6610
# 1          RL  Land Use        100  India          5110    Area       6610
# 2          RL  Land Use        100  India          5110    Area       6610
# 3          RL  Land Use        100  India          5110    Area       6610
# 4          RL  Land Use        100  India          5110    Area       6610
#
#                 Item  Year Code  Year     Unit     Value Flag  \
# 0  Agricultural land       1961  1961  1000 ha  174952.0    W
# 1  Agricultural land       1962  1962  1000 ha  176482.0    W
# 2  Agricultural land       1963  1963  1000 ha  176154.0    W
# 3  Agricultural land       1964  1964  1000 ha  176712.0    W
# 4  Agricultural land       1965  1965  1000 ha  177177.0    W
#
#                                     Flag Description
# 0  Data reported on country official publications...
# ...

# %%
data.describe()
# Out:
#        Area Code  Element Code    Item Code    Year Code         Year  \
# count       89.0          89.0    89.000000    89.000000    89.000000
# mean       100.0        5110.0  6630.224719  1994.887640  1994.887640
# std          0.0           0.0    28.523417    16.355037    16.355037
# min        100.0        5110.0  6610.000000  1961.000000  1961.000000
# 25%        100.0        5110.0  6610.000000  1983.000000  1983.000000
# 50%        100.0        5110.0  6610.000000  1997.000000  1997.000000
# 75%        100.0        5110.0  6670.000000  2008.000000  2008.000000
# max        100.0        5110.0  6670.000000  2019.000000  2019.000000
#
#                Value
# count      89.000000
# mean   135587.303371
# std     62291.085148
# min     45847.400000
# 25%     49842.900000
# 50%    179573.000000
# 75%    180462.000000
# max    181586.000000
